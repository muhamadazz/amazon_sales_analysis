# %%
# AMAZON SALES ANALYSIS
# Author: Muhamad Fahraz Firdaus
# Date: 20-04-2025
# source : https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset

# 📦 IMPORT LIBRARY
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown
import warnings
warnings.filterwarnings('ignore')

# 📥 LOAD DATASET
df = pd.read_csv('/content/drive/MyDrive/portofolio data analysis/amazon sales analysis/data/amazon.csv')

# %% [markdown]
# 🧠 **DATA UNDERSTANDING**

# %%
# --- Informasi Umum ---
print("🧾 INFORMASI DATASET")
df.info()

print("\n🔍 5 Data Teratas")
df.head()
# Out:
# 🧾 INFORMASI DATASET
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
# --- Statistik Deskriptif ---
print("\n📊 STATISTIK DESKRIPTIF (Awal)")
df.describe(include='all')
# Out:
# 📊 STATISTIK DESKRIPTIF (Awal)
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B083342NKJ  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
# --- Cek Missing Values ---
print("\n🚨 MISSING VALUES")
df.isnull().sum()
# Out:
# 🚨 MISSING VALUES
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# --- Cek Duplikat ---
print("\n📌 CEK DUPLIKAT")
print(f"Jumlah duplikat baris: {df.duplicated().sum()}")
# Out:
# 📌 CEK DUPLIKAT
# Jumlah duplikat baris: 0

# %% [markdown]
# **DATA CLEANING AMAZON SALES**

# %%
# --- Konversi Kolom Harga dan Rating ke Numerik ---
def clean_price(x):
    return float(str(x).replace("₹", "").replace(",", "").strip()) if pd.notnull(x) else np.nan

def clean_percentage(x):
    return float(str(x).replace("%", "").strip()) if pd.notnull(x) else np.nan

def clean_rating_count(x):
    return int(str(x).replace(",", "").strip()) if pd.notnull(x) else np.nan

df['discounted_price'] = df['discounted_price'].apply(clean_price)
df['actual_price'] = df['actual_price'].apply(clean_price)
df['discount_percentage'] = df['discount_percentage'].apply(clean_percentage)
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
df['rating_count'] = df['rating_count'].apply(clean_rating_count)
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2       24269.0
# ...

# %%
# --- Imputasi Nilai Hilang ---
df['rating_count'].fillna(df['rating_count'].median(), inplace=True)
df['rating'].fillna(df['rating'].median(), inplace=True)

# --- Cek Kembali Missing Values ---
print("\n✅ MISSING VALUES (SETELAH PEMBERSIHAN)")
print(df.isnull().sum())
# Out:
# ✅ MISSING VALUES (SETELAH PEMBERSIHAN)
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# --- Statistik Deskriptif setelah Dibersihkan ---
print("\n📊 STATISTIK DESKRIPTIF (Setelah Dibersihkan)")
df[['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']].describe()
# Out:
# 📊 STATISTIK DESKRIPTIF (Setelah Dibersihkan)
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1465.000000
# mean        3125.310874    5444.990635            47.691468     4.096587
# std         6944.304394   10874.826864            21.635905     0.291574
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1650.000000            50.000000     4.100000
# 75%         1999.000000    4295.000000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1465.000000
# mean    18277.634812
# std     42727.398216
# min         2.000000
# 25%      1191.000000
# 50%      5179.000000
# 75%     17325.000000
# max    426973.000000

# %%
# --- Unik Value Beberapa Kolom ---
print("\n🔢 JUMLAH NILAI UNIK PER KOLOM TERPILIH")
for col in ['product_id', 'product_name', 'category', 'user_id', 'user_name', 'review_id']:
    print(f"{col}: {df[col].nunique()} unik")
# Out:
# 🔢 JUMLAH NILAI UNIK PER KOLOM TERPILIH
# product_id: 1351 unik
# product_name: 1337 unik
# category: 211 unik
# user_id: 1194 unik
# user_name: 1194 unik
# review_id: 1194 unik

# %%
# --- Distribusi Kategori Produk Teratas ---
print("\n📂 10 KATEGORI TERBANYAK")
print(df['category'].value_counts().head(10))
# Out:
# 📂 10 KATEGORI TERBANYAK
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                        233
# Electronics|WearableTechnology|SmartWatches                                                               76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                      68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                             63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                              52
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                               49
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|MixerGrinders                                  27
# Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Mice                            24
# ...

# %% [markdown]
# 📊 **Exploratory Data Analysis (EDA)**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# Style
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
#Distribusi Rating Produk
sns.histplot(df['rating'], bins=20, kde=True, color='skyblue')
plt.title('Distribusi Rating Produk')
plt.xlabel('Rating')
plt.ylabel('Jumlah Produk')
plt.show()

# %%
#Distribusi Harga dan Diskon
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(df['actual_price'], bins=30, kde=True, ax=axes[0], color='salmon')
axes[0].set_title('Distribusi Harga Asli')
axes[0].set_xlabel('Harga (₹)')

sns.histplot(df['discount_percentage'], bins=30, kde=True, ax=axes[1], color='lightgreen')
axes[1].set_title('Distribusi Diskon (%)')
axes[1].set_xlabel('Diskon (%)')

plt.tight_layout()
plt.show()

# %%
#3. Korelasi antar variable
sns.heatmap(df[['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']].corr(),
            annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Korelasi Antar Variabel Numerik')
plt.show()

# %%
#10 Kategori dengn produk terbanyak
top_categories = df['category'].value_counts().head(10)

sns.barplot(x=top_categories.values, y=top_categories.index, palette='viridis')
plt.title('10 Kategori Produk Terbanyak')
plt.xlabel('Jumlah Produk')
plt.ylabel('Kategori')
plt.show()

# %%
#Produk dengan Rating Tertinggi
top_rated = df.sort_values(by=['rating', 'rating_count'], ascending=[False, False])
display(Markdown("### 🏆 Produk dengan Rating Tertinggi dan Banyak Review"))
display(top_rated[['product_name', 'rating', 'rating_count', 'discounted_price']].head(10))
# Out:
# ### 🏆 Produk dengan Rating Tertinggi dan Banyak Review
#                                            product_name  rating  rating_count  \
# 324   REDTECH USB-C to Lightning Cable 3.3FT, [Apple...     5.0        5179.0
# 775   Amazon Basics Wireless Mouse | 2.4 GHz Connect...     5.0          23.0
# 174   Syncwire LTG to USB Cable for Fast Charging Co...     5.0           5.0
# 1145  Swiffer Instant Electric Water Heater Faucet T...     4.8       53803.0
# 1299  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...     4.8        3964.0
# 1201  Oratech Coffee Frother electric, milk frother ...     4.8          28.0
# 459   Spigen EZ Fit Tempered Glass Screen Protector ...     4.7        7779.0
# 249   Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...     4.7        5935.0
# 1388  Campfire Spring Chef Prolix Instant Portable W...     4.7        2591.0
# 1275  Multifunctional 2 in 1 Electric Egg Boiling St...     4.7        2300.0
#
#       discounted_price
# 324              249.0
# ...

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='discount_percentage', y='rating', alpha=0.5)
plt.title('Hubungan Diskon vs Rating')
plt.xlabel('Diskon (%)')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# **📊 Insight – Amazon Sales**
#
# **1. Diskon vs Rating (Scatter Plot)**
#
# “Apakah diskon tinggi berdampak pada kepuasan konsumen (rating)?”
#
# *   Terlihat sebaran rating cukup stabil di antara semua tingkat diskon.
# *   Tidak ada hubungan yang jelas antara diskon dan rating → tidak semua diskon tinggi berarti rating bagus. Artinya, kualitas tetap jadi pertimbangan utama, bukan hanya harga.
#
# 📌 Insight: Diskon tidak menjamin peningkatan kepuasan pelanggan.
#
#
# **2. 💸 Distribusi Harga Asli (Hist + KDE)**
#
# “Berapa harga mayoritas produk sebelum diskon?”
#
# *   Mayoritas produk memiliki harga asli di bawah ₹5000.
# *   Ada sedikit outlier hingga ₹140.000.
#
# 📌 Insight: Pasar Amazon sangat didominasi produk-produk harga terjangkau.
#
# **3. 🏷️ Distribusi Diskon (%)**
#
# “Bagaimana strategi harga dari seller di Amazon?”
#
#
# *   Distribusi diskon menunjukkan peak di 40–60%, artinya mayoritas produk didiskon setengah harga.
# *   Sedikit produk yang memiliki diskon sangat tinggi (>80%).
#
#
# 📌 Insight: Diskon moderat (40–60%) merupakan strategi yang umum dan mungkin paling optimal.
#
# **4.  🎯Top 10 Kategori Produk Terbanyak**
#
# “Kategori produk apa yang paling banyak dijual?”
#
# Produk terbanyak berasal dari:
#
#
# *   USB Cables
# *   Smart Watches
# *  Smartphones
#
# Didominasi oleh elektronik dan aksesoris.
#
# 📌 Insight: Produk teknologi & aksesoris adalah kategori paling kompetitif di Amazon.
